# %%
import pandas as pd
import numpy as np

retail_data = pd.read_excel('Project 2 - Retail Sales Dataset.xlsx')

# %%
retail_data.head()
# Out:
#   ORDER_NUMBER  SHIPMENT_NUMBER  ITEM_NUMBER INVOICE_NUMBER  INVOICE_DATE  \
# 0      6735217         20171129       428714        6735217      20171129
# 1      6165708         20190626       408872        6165708      20190626
# 2      6517073         20180910       354274        6517073      20180910
# 3      6723693         20200513       222679        6723693      20200513
# 4      6766514         20190128       431999        6766514      20190128
#
#    ORDER_DATE  CUSTOMER_NUMBER  CUSTOMER_LOCATION  CUSTOMER_DEPARTMENT  \
# 0    20171128              410                 10                    9
# 1    20190624             1375                  1                   83
# 2    20180908             2196                  1                   70
# 3    20200509             1934                 50                   70
# 4    20190125            75379                201                    0
#
#   CUSTOMER_PROVINCE  ... COMPANY_CODE       COMPANY_NAME COMPANY_NUMBER  \
# ...

# %%
#To find the count of zeros in all the columns
for column_name in retail_data.columns:
    column = retail_data[column_name]
    # Get the count of Zeros in column 
    count = (column == 0).sum()
    print('Count of zeros in column ', column_name, ' is : ', count)
# Out:
# Count of zeros in column  ORDER_NUMBER  is :  0
# Count of zeros in column  SHIPMENT_NUMBER  is :  0
# Count of zeros in column  ITEM_NUMBER  is :  0
# Count of zeros in column  INVOICE_NUMBER  is :  0
# Count of zeros in column  INVOICE_DATE  is :  0
# Count of zeros in column  ORDER_DATE  is :  0
# Count of zeros in column  CUSTOMER_NUMBER  is :  0
# Count of zeros in column  CUSTOMER_LOCATION  is :  0
# Count of zeros in column  CUSTOMER_DEPARTMENT  is :  2149
# Count of zeros in column  CUSTOMER_PROVINCE  is :  0
# Count of zeros in column  ITEM_DESCRIPTION  is :  0
# Count of zeros in column  SHIPPING_REGION_IDENTIFIER  is :  0
# Count of zeros in column  SHIPPING_REGION_CODE  is :  0
# Count of zeros in column  SHIPPING_REGION_NAME  is :  0
# Count of zeros in column  SHIPPING_UNIT_MEASURE  is :  0
# Count of zeros in column  SHIPPING_PACK_QUANTITY  is :  0
# Count of zeros in column  ITEM_UNIT_QUANTITY  is :  0
# Count of zeros in column  ITEM_DEPARTMENT  is :  31
# ...

# %%
#To find the count Null values in all the columns
retail_data.isnull().sum()
# Out:
# ORDER_NUMBER                   0
# SHIPMENT_NUMBER                0
# ITEM_NUMBER                    0
# INVOICE_NUMBER                 0
# INVOICE_DATE                   0
# ORDER_DATE                     0
# CUSTOMER_NUMBER                0
# CUSTOMER_LOCATION              0
# CUSTOMER_DEPARTMENT            0
# CUSTOMER_PROVINCE             52
# ITEM_DESCRIPTION              72
# SHIPPING_REGION_IDENTIFIER     0
# SHIPPING_REGION_CODE           0
# SHIPPING_REGION_NAME           0
# SHIPPING_UNIT_MEASURE          0
# SHIPPING_PACK_QUANTITY         0
# ITEM_UNIT_QUANTITY             0
# ITEM_DEPARTMENT                0
# ITEM_SECTION                   0
# ITEM_SECTION_MODULE            0
# ITEM_GROUP                     0
# ITEM_SEQUENCE                  0
# ITEM_STOCK_STATUS              0
# WAREHOUSE_IDENTIFIER           0
# WAREHOUSE_NUMBER               0
# WAREHOUSE_NAME                 0
# WAREHOUSE_REGION_NAME          0
# VENDOR_IDENTIFIER              0
# ...

# %%
#To find the count of  "?" in all the columns
for column_name in retail_data.columns:
    column = retail_data[column_name]
    count = (column == '?').sum()
    print('Count of zeros in column ', column_name, ' is : ', count)
# Out:
# Count of zeros in column  ORDER_NUMBER  is :  0
# Count of zeros in column  SHIPMENT_NUMBER  is :  0
# Count of zeros in column  ITEM_NUMBER  is :  0
# Count of zeros in column  INVOICE_NUMBER  is :  0
# Count of zeros in column  INVOICE_DATE  is :  0
# Count of zeros in column  ORDER_DATE  is :  0
# Count of zeros in column  CUSTOMER_NUMBER  is :  0
# Count of zeros in column  CUSTOMER_LOCATION  is :  0
# Count of zeros in column  CUSTOMER_DEPARTMENT  is :  0
# Count of zeros in column  CUSTOMER_PROVINCE  is :  0
# Count of zeros in column  ITEM_DESCRIPTION  is :  0
# Count of zeros in column  SHIPPING_REGION_IDENTIFIER  is :  0
# Count of zeros in column  SHIPPING_REGION_CODE  is :  0
# Count of zeros in column  SHIPPING_REGION_NAME  is :  0
# Count of zeros in column  SHIPPING_UNIT_MEASURE  is :  0
# Count of zeros in column  SHIPPING_PACK_QUANTITY  is :  0
# Count of zeros in column  ITEM_UNIT_QUANTITY  is :  0
# Count of zeros in column  ITEM_DEPARTMENT  is :  0
# ...

# %%
#To find the blank cells in all the columns
for column_name in retail_data.columns:
    column = retail_data[column_name]
    count = (column == ' ').sum()
    print('Count of zeros in column ', column_name, ' is : ', count)
# Out:
# Count of zeros in column  ORDER_NUMBER  is :  0
# Count of zeros in column  SHIPMENT_NUMBER  is :  0
# Count of zeros in column  ITEM_NUMBER  is :  0
# Count of zeros in column  INVOICE_NUMBER  is :  0
# Count of zeros in column  INVOICE_DATE  is :  0
# Count of zeros in column  ORDER_DATE  is :  0
# Count of zeros in column  CUSTOMER_NUMBER  is :  0
# Count of zeros in column  CUSTOMER_LOCATION  is :  0
# Count of zeros in column  CUSTOMER_DEPARTMENT  is :  0
# Count of zeros in column  CUSTOMER_PROVINCE  is :  0
# Count of zeros in column  ITEM_DESCRIPTION  is :  0
# Count of zeros in column  SHIPPING_REGION_IDENTIFIER  is :  0
# Count of zeros in column  SHIPPING_REGION_CODE  is :  0
# Count of zeros in column  SHIPPING_REGION_NAME  is :  0
# Count of zeros in column  SHIPPING_UNIT_MEASURE  is :  0
# Count of zeros in column  SHIPPING_PACK_QUANTITY  is :  0
# Count of zeros in column  ITEM_UNIT_QUANTITY  is :  0
# Count of zeros in column  ITEM_DEPARTMENT  is :  0
# ...

# %%
# To verify of the if all "?" have been replaced
for column_name in retail_data_transformed:
    column = retail_data_transformed[column_name]
    # Get the count of Zeros in column 
    count = (column == '?').sum()
    print('Count of zeros in column ', column_name, ' is : ', count)
# Out:
# Count of zeros in column  ORDER_NUMBER  is :  0
# Count of zeros in column  SHIPMENT_NUMBER  is :  0
# Count of zeros in column  ITEM_NUMBER  is :  0
# Count of zeros in column  INVOICE_NUMBER  is :  0
# Count of zeros in column  INVOICE_DATE  is :  0
# Count of zeros in column  ORDER_DATE  is :  0
# Count of zeros in column  CUSTOMER_NUMBER  is :  0
# Count of zeros in column  CUSTOMER_LOCATION  is :  0
# Count of zeros in column  CUSTOMER_DEPARTMENT  is :  0
# Count of zeros in column  CUSTOMER_PROVINCE  is :  0
# Count of zeros in column  ITEM_DESCRIPTION  is :  0
# Count of zeros in column  SHIPPING_REGION_IDENTIFIER  is :  0
# Count of zeros in column  SHIPPING_REGION_CODE  is :  0
# Count of zeros in column  SHIPPING_REGION_NAME  is :  0
# Count of zeros in column  SHIPPING_UNIT_MEASURE  is :  0
# Count of zeros in column  SHIPPING_PACK_QUANTITY  is :  0
# Count of zeros in column  ITEM_UNIT_QUANTITY  is :  0
# Count of zeros in column  ITEM_DEPARTMENT  is :  0
# ...

# %% [markdown]
# ### Cleaning the Dataset

# %%
#To replace "?" with "UNKNOWN" in the columns
Retail_Sales_Dataset_Cleaned = retail_data.replace(['?'], 'UNKNOWN')

#To change the negative values into absolute(+ve) values in these columns

Retail_Sales_Dataset_Cleaned['AVERAGE_COST_PRICE'] = Retail_Sales_Dataset_Cleaned['AVERAGE_COST_PRICE'].abs()

Retail_Sales_Dataset_Cleaned['ORDER_QUANTITY'] = Retail_Sales_Dataset_Cleaned['ORDER_QUANTITY'].abs()

Retail_Sales_Dataset_Cleaned['SHIPPED_QUANTITY'] = Retail_Sales_Dataset_Cleaned['SHIPPED_QUANTITY'].abs()

Retail_Sales_Dataset_Cleaned['SALES_AMOUNT'] = Retail_Sales_Dataset_Cleaned['SALES_AMOUNT'].abs()

#To replace blank space with "UNKNOWN" in the columns
Retail_Sales_Dataset_Cleaned['ITEM_STOCK_STATUS'] = Retail_Sales_Dataset_Cleaned['ITEM_STOCK_STATUS'].replace([' '], 'UNKNOWN')

# %%
Retail_Sales_Dataset_Cleaned.to_excel('Retail_Sales_Dataset_Cleaned.xlsx', index=False)
